# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# Out:
# env: XLA_PYTHON_CLIENT_MEM_FRACTION=0.2

# %%
jax.default_backend()
# Out:
# 'gpu'

# %% [markdown]
# From `lovely-numpy`: https://github.com/xl0/lovely-numpy/blob/master/nbs/03_utils.utils.ipynb

# %%
#| echo: false
#| output: asis
show_doc(ansi_color)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### ansi_color
#
# >      ansi_color (s:str, col:str, use_color=True)
#
# Very minimal ANSI color support

# %%
#| echo: false
#| output: asis
show_doc(sparse_join)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### sparse_join
#
# >      sparse_join (lst, sep=' ')

# %%
#| echo: false
#| output: asis
show_doc(pretty_str)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### pretty_str
#
# >      pretty_str (x)
#
# A slightly better way to print `float`-y values.
# Works for `np.ndarray`, `torch.Tensor`, `jax.DeviceArray`, and scalars.

# %%
#| echo: false
#| output: asis
show_doc(sci_mode)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### sci_mode
#
# >      sci_mode (f:float)

# %%
#| echo: false
#| output: asis
show_doc(to_str)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### to_str
#
# >      to_str (x, color=True, ddof=0)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | x |  |  | Input |
# | color | bool | True | ANSI color highlighting |
# | ddof | int | 0 | For "std" unbiasing |

# %%
to_str(jnp.array([[0.],[0.]]))
# Out:
# '\x1ball_zeros\x1b'

# %%
to_str(jnp.array([[1.],[4.],[3.]]))
# Out:
# 'x∈[1.000, 4.000] μ=2.667 σ=1.247'

# %%
#| echo: false
#| output: asis
show_doc(str_tree)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/utils.py#L79){target="_blank" style="float:right; font-size:smaller"}
#
# ### str_tree
#
# >      str_tree (tree)
