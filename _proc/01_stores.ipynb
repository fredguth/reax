# %% [raw]
# ---
# description: The `Reax` stores implementation became its own package, [Sveltish](fredguth.github.io/sveltish).  It
#   is better documented ther, but I kept a copy here to make it easier to follow along.
# output-file: stores.html
# title: stores
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Writable)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### Writable
#
# >      Writable (**kwargs)
#
# A base class for all stores.

# %%
#| echo: false
#| output: asis
show_doc(Readable)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L101){target="_blank" style="float:right; font-size:smaller"}
#
# ### Readable
#
# >      Readable (**kwargs)
#
# A base class for all stores.

# %%
#| echo: false
#| output: asis
show_doc(Store)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### Store
#
# >      Store (**kwargs)
#
# A base class for all stores.

# %%
#| echo: false
#| output: asis
show_doc(StoreProtocol)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### StoreProtocol
#
# >      StoreProtocol (*args, **kwargs)
#
# The Svelte Store ~~contract~~ protocol.

# %%
#| echo: false
#| output: asis
show_doc(safe_not_equal)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### safe_not_equal
#
# >      safe_not_equal (a, b)
#
# Check if `a` is not equal to `b`

# %%
#| echo: false
#| output: asis
show_doc(Derived)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L112){target="_blank" style="float:right; font-size:smaller"}
#
# ### Derived
#
# >      Derived (s:Union[Store,list[Store]], fn:Callable)
#
# A Derived Store.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | s | Union[Store, list[Store]] | source store(s) |
# | fn | Callable | a callback that takes the source store(s) values and returns the derived value |
# | **Returns** | **None** |  |

# %%
#| echo: false
#| output: asis
show_doc(Readable)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L101){target="_blank" style="float:right; font-size:smaller"}
#
# ### Readable
#
# >      Readable (initial_value:T, start:Notifier)
#
# A Readable Store.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | initial_value | T | initial value of the store |
# | start | Notifier | function called when the first subscriber is added |
# | **Returns** | **None** |  |

# %%
#| echo: false
#| output: asis
show_doc(Writable)
# Out:
# ---
#
# [source](https://github.com/fredguth/reax/blob/main/reax/stores.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### Writable
#
# >      Writable (initial_value:Any=None, start:Notifier=<function <lambda>>)
#
# A Writable Store.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | initial_value | Any | None | initial value of the store |
# | start | Notifier | <lambda> | A Notifier (Optional) |
# | **Returns** | **None** |  |  |
